# %% [markdown]
# # Python Introduction

# %% [markdown]
# ### Topic 1

# %%
print("Good Morning")
# Out:
# Good Morning

# %%
print("shift+enter")
# Out:
# shift+enter

# %%
a=5
b=45
print(a+b)
# Out:
# 50

# %%
print(a)
# Out:
# 5

# %%
a=76

# %%
print(a)
# Out:
# 76

# %%
print(z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print(z)
#
# NameError: name 'z' is not defined

# %%
print(a)
print(w)
print(b)
# Out:
# 76
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 print(a)
# ----> 2 print(w)
#       3 print(b)
#
# NameError: name 'w' is not defined

# %% [markdown]
# # output function: print()

# %%
name="rahul"
print(name)
# Out:
# rahul

# %%
print("my name is",name)
# Out:
# my name is rahul

# %%
fname="rahul"
lname="Dravid"
print(f'first name is {fname} and last name is {lname}')
# Out:
# first name is rahul and last name is Dravid

# %%
print("first name is",fname,"and last name is",lname)
# Out:
# first name is rahul and last name is Dravid

# %%
a=6
b=7
print(f'the sum of {a} and {b} is:',a+b)
# Out:
# the sum of 6 and 7 is: 13

# %% [markdown]
# # type function

# %%
x=5
type(x)
# Out:
# int

# %%
y=False
type(y)
# Out:
# bool

# %%
z=True
type(z)
# Out:
# bool

# %%
s="delhi"
type(s)
# Out:
# str

# %%
type(b)
# Out:
# int

# %% [markdown]
# # Variables

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
1fname="x"
# Out:
#   Cell In[2], line 1
#     1fname="x"
#     ^
# SyntaxError: invalid decimal literal

# %%
fname1="xyz"

# %%
print(fname1)
# Out:
# xyz

# %%
_=100
print(_)
# Out:
# 100

# %%
user_name="amit"

# %%
var$=67

# %%
# %var%=23

# %%
a=12
b=12
c=12

# %%
a=b=c=12
print(a,b,c)
# Out:
# 12 12 12

# %%
x=44
y=88

# %%
x,y=44,88
print("the value  of x",x)
print("the value  of y",y)
# Out:
# the value  of x 44
# the value  of y 88

# %% [markdown]
# # Comments--
# #### Non executable statement

# %%
# Single line comment
# fname is a variable and rahul is data 
fname="rahul"
lname="Dravid"
print(f'first name is {fname} and last name is {lname}')
# Out:
# first name is rahul and last name is Dravid

# %%
""" line 1
line2
line3 """
a=3
b=5 # value of b is 5
print(a,b)
# Out:
# 3 5

# %%
name="kishan"
name[3] # accessing "h" char
# Out:
# 'h'

# %% [markdown]
# # bool function

# %%
bool(0)
# Out:
# False

# %%
bool(9) #  bool() return true for all the values except zero
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
bool("diya")
# Out:
# True

# %%
bool(0.0)
# Out:
# False

# %%
bool(1.5)
# Out:
# True

# %%
bool(-34)
# Out:
# True

# %%
bool(False)
# Out:
# False

# %%
3>6
# Out:
# False

# %%
True==1
# Out:
# True

# %%
True==0
# Out:
# False

# %%
False==0
# Out:
# True

# %% [markdown]
# # strings

# %%
fruit="apple "
colour='red'

# %%
print(Fruit)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 print(Fruit)
#
# NameError: name 'Fruit' is not defined

# %%
print(fruit,colour)
# Out:
# apple red

# %%
print(fruit*4) # repeaters
# Out:
# apple apple apple apple

# %% [markdown]
# # String

# %%
str1="Good Morning"

# %%
# Access the char M
str1[5]
# Out:
# 'M'

# %%
str1[-4]
# Out:
# 'n'

# %%
str1[0]
# Out:
# 'G'

# %%
str1[9]
# Out:
# 'i'

# %% [markdown]
# # String Slicing

# %%
str2="HELLO PYTHON"

# %%
str2[:] # Access all the char in the string
# Out:
# 'HELLO PYTHON'

# %%
str2[2:]
# Out:
# 'LLO PYTHON'

# %%
str2[:7]
# Out:
# 'HELLO P'

# %%
str2[4:9]
# Out:
# 'O PYT'

# %%
str2[0:9:2]
# Out:
# 'HLOPT'

# %%
str2[::2]
# Out:
# 'HLOPTO'

# %%
str2[3:10:3]
# Out:
# 'LPH'

# %%
str2[::-1] # Reverse the string using slicing
# Out:
# 'NOHTYP OLLEH'

# %%
# String Concatination

# %%
fname="Ajay "
lname="Kumar"

# %%
full_name=fname+lname
print(full_name)
# Out:
# Ajay Kumar

# %%
x="amit"+" "+"kumar"
print(x)
# Out:
# amit kumar

# %% [markdown]
# # Menbership Operator

# %%
fname
# Out:
# 'Ajay '

# %%
"j" in fname
# Out:
# True

# %%
"z" in fname
# Out:
# False

# %%
"x" not in fname
# Out:
# True

# %% [markdown]
# # String Functions

# %%
str1='good morning'

# %%
str1.upper()
# Out:
# 'GOOD MORNING'

# %%
str2="HELLO PYTHON"

# %%
str2.lower()
# Out:
# 'hello python'

# %%
str2.count("O")
# Out:
# 2

# %%
str2.count("P")
# Out:
# 1

# %%
str2.index("Y") # RETURNS index value for the given argument

# %%
str2.index("H") # returns first occurance of char
# Out:
# 0

# %%
str3="                 DATAMITES                 "

# %%
str3.strip() # by default it removes whitspaces before the string and end of the string
# Out:
# 'DATAMITES'

# %%
str4="************************Datamites**********************"

# %%
str4.strip("*")
# Out:
# 'Datamites'

# %%
str4.lstrip()
# Out:
# '************************Datamites**********************'

# %%
str4.rstrip()
# Out:
# '************************Datamites**********************'

# %%
str5="one two three four five"

# %%
str5.split() # Return a list of the substrings in the string
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
str6="arun:bhavya:chethan:diya"

# %%
str6.split(":")
# Out:
# ['arun', 'bhavya', 'chethan', 'diya']

# %%
str7="welcome to datamites at Marathahalli branch "

# %%
str7.partition("to") # Partition the string into three parts
# Out:
# ('welcome ', 'to', ' datamites at Marathahalli branch ')

# %%
str7.startswith("we")  #Return True if S starts with the specified prefix, False otherwise.
# Out:
# True

# %%
str7.endswith("t")
# Out:
# False

# %% [markdown]
# # Python Operators

# %% [markdown]
# ## Arithematic Operators

# %%
a=5
b=2
print("a+b= ",a+b)
print("a-b= ",a-b)
print("a*b= ",a*b)
print("a/b= ",a/b)
print("a%b= ",a%b)
print("a**b= ",a**b)
print("a//b= ",a//b)
# Out:
# a+b=  7
# a-b=  3
# a*b=  10
# a/b=  2.5
# a%b=  1
# a**b=  25
# a//b=  2

# %% [markdown]
# ## Logical Operators

# %%
a=True
b=False
print("a=",a)
print("b=",b)
print("a and b = ",a and b)
print("a or b = ",a or b)
print("not a = ", not a)
# Out:
# a= True
# b= False
# a and b =  False
# a or b =  True
# not a =  False

# %% [markdown]
# # Input function()

# %%
user_name=input("enter the user the name")
print(user_name)
print("the data type of user_name is :",type(user_name))
# Out:
# enter the user the name arun kumar
# arun kumar
# the data type of user_name is : <class 'str'>

# %%
age=input("enter the value of age")
print(age)
print("the data type of age is :",type(age))
# Out:
# enter the value of age 32
# 32
# the data type of age is : <class 'str'>

# %%
age=int(input("enter the value of age"))
print(age)
print("the data type of age is :",type(age))
# Out:
# enter the value of age 21
# 21
# the data type of age is : <class 'int'>

# %%
marks=float(input("enter the marks"))
print("marks=",marks)
print("the type of marks is",type(marks))
# Out:
# enter the marks 34.56
# marks= 34.56
# the type of marks is <class 'float'>

# %% [markdown]
# # Conditional Statements

# %% [markdown]
# ## 1. If statement

# %%
value=int(input("enter the numeric value"))
if value<5:
    print("the value is lesser than 5")
print("this statement is independent statement")
# Out:
# enter the numeric value 3
# the value is lesser than 5
# this statement is independent statement

# %%
age=int(input("enter the value of age"))
if age>=18:
    print("Executes if block,if condition is true")
    print("you are an adult")
# Out:
# enter the value of age 34
# Executes if block,if condition is true
# you are an adult

# %% [markdown]
# ## 2. If-else Statements

# %%
print("write a program to check whether the given number is positive or negative")
num=int(input("enter the number"))

if num>0:
    print("the given number is +ve")
else:
    print("The given number is -ve")

print("end of the program")
# Out:
# write a program to check whether the given number is positive or negative
# enter the number -4
# The given number is -ve
# end of the program

# %%
name="HARSHA"
if "j" in name:
    print("the character j is present")
else:
    print("the character j is not present")
# Out:
# the character j is not present

# %%
print("write a program to check whether the given number is even or odd")
num=int(input("enter the number"))

if  num%2==0:
    print("even number")
else:
    print("odd number")
# Out:
# write a program to check whether the given number is even or odd
# enter the number 33
# odd number

# %%
print("write a program to validate username and password")
user_name="sahana"
password="rohit1234"

if user_name=="rohit" and password=="rohit1234":
    print(" both user name and password are correct")
else:
    print("Incorrect Username or password")

# %% [markdown]
# ## if-elif-else Block

# %%
print("write a program to check whether the given number is positive or negative or zero")
num=int(input("enter the number"))

if num>0:
    print("the given number is +ve")
elif num<0:
    print("The given number is -ve")
else:
    print("The number is zero")

print("end of the program")
# Out:
# write a program to check whether the given number is positive or negative or zero
# enter the number -4
# The given number is -ve
# end of the program

# %%
score=int(input("enter the score"))

if score>=90:
    print("Grade A+")
elif score >=80:
    print("Grade A")
elif score >=70:
    print("Grade B+")
elif score>=60:
    print("Grade B")
elif score >=35:
    print("Grade C")
else:
    print("FAILED")
# Out:
# enter the score 76
# Grade B+

# %% [markdown]
# ## Nested If statements

# %%
attendance=int(input("enter the attendance value"))

if attendance>=75:
    marks=float(input("enter the marks"))
    if marks>35:
        print("PASS")
    else:
        print("Failed")

else:
    print("Not eligible to write Exams")
# Out:
# enter the attendance value 88
# enter the marks 46
# PASS

# %% [markdown]
# # Type Casting

# %%
12+7+True
# Out:
# 20

# %%
12+7+True+45.5
# Out:
# 65.5

# %%
3+False
# Out:
# 3

# %%
a=13.55
c=int(a)   # convert float to integer
print(c,type(c))
s=str(a) # convert float to string
print(s,type(s))
d=bool(a)  # convert float to boolean
print(d,bool(d))
s
# Out:
# 13 <class 'int'>
# 13.55 <class 'str'>
# True True
# '13.55'

# %%
b=45
z=float(b)
print(z,type(z))
# Out:
# 45.0 <class 'float'>

# %%
pwd
# Out:
# 'C:\\Users\\Datamites\\akshatha'
